# %% [markdown]
# # Exploratory Data Analysis of Fruits Prices
#
# This notebook loads the cleaned fruit prices data and performs exploratory analysis.

# %% [markdown]
# ## Price Trends

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned data
df = pd.read_csv('data/processed/fruits_clean.csv')
df.head()

# %%
df.info()

# %%
df.describe()

# %%
# Check for missing values
df.isnull().sum()

# %%
# Number of unique products
df['product'].nunique()

# %%
# Time range
df['date'].min(), df['date'].max()
